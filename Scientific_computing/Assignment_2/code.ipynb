# %%
import numpy as np
import matplotlib.pyplot as plt
from Functions import Simulation

# %% [markdown]
# # Definitions and Initializations

# %%
#Regarding the Grid
N = 41                      #Number of grid points of a single line of the mesh grid
x_range = (0., 40.)           #Range in the x direction
y_range = (0., 40.)           #Range in the y direction

#Regarding the Time
dt = 0.01                   #Time step
Nt = 2000                   #Total time

#Regarding the Parameters/Constants
C = 4.5                     
Dp = 1.0
Dq = 8.0
K_values = [7., 8., 9., 10., 11., 12.]

# %% [markdown]
# # Simulations and plots

# %%
sim = Simulation(N, x_range, y_range, dt, Nt, C, Dp, Dq)

for K in K_values:
    pd, qd = sim.euler(K)
    sim.plot_results(K, pd, qd)
